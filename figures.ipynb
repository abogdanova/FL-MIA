# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)

plt.hlines(AveragedTrain, 0, 36, color='grey', linestyles='--', label='Averaged Model')
plt.plot(NFTrain, label='Centralized Model')
plt.plot(NFTrainReg, linestyle=':', color='#2980B9', label='Regularized Model')
plt.plot(Ind0Train, label='Individual Average')
plt.plot(Ind0TrainReg, color='orange', linestyle=':', label='Individual Regularized')
plt.plot(CycTrTrain, linestyle='--', label='Weight Transfer')
plt.plot(FedTrainE1B32, marker='o', markersize=4, label='Federated Learning')
plt.legend(ncol=2)
plt.ylabel('Train Loss')
plt.xlabel('Epochs')
plt.title("Train Loss (IID)")

plt.subplot(1,3,2)
plt.hlines(AveragedTest, 0, 36, color='grey', linestyles='--', label="Averaged Model")
plt.plot(NFTest, label='Centralized Model')
plt.plot(NFTestReg, color='#2980B9', linestyle=':', label='Regularized Model')
plt.plot(Ind0Test, label='Individual Average')
plt.plot(Ind0TestReg, color='orange', linestyle=':', label='Individual Regularized')
plt.plot(CycTrTest, linestyle='--', label='Weight Transfer')
plt.plot(FedTestE1B32, marker='o', markersize=4, label='Federated Learning')
plt.ylabel('Validation Loss')
plt.xlabel('Epochs')
plt.title("Validation Loss (IID)")
plt.legend(ncol=2, loc='upper left')

plt.subplot(1,3,3)
plt.hlines(AveragedAccuracy, 0, 36, color='grey', linestyles='--', label='Averaged Model')
plt.plot(NFAccuracy, label='Centralized Model')
plt.plot(NFAccuracyReg, linestyle=':', color='#2980B9', label='Regularized Model')
plt.plot(Ind0Accuracy, label='Individiual Average')
plt.plot(Ind0AccuracyReg, color='orange', linestyle=':', label='Individiual Regularized')
plt.plot(CycTrAccuracy, linestyle='--', label='Weight Transfer')
plt.plot(FedAccuracyE1B32, marker='o', markersize=4, label='Federated Learning')
plt.ylabel('Validation Accuracy')
plt.xlabel('Epochs')
plt.title("Validation Accuracy (IID)")
plt.legend(ncol=2)

plt.show()

# %%
# Varying amount of computation per client in federated setting

NFTrainMin = np.min(NFTrainReg)
NFTestMin = np.min(NFTestReg)
NFAccuracyMax = np.max(NFAccuracyReg)

FedTrainE1B64 = [1.9551773131052652, 1.5109496791203816, 1.3343133937199911, 1.2280411218643188, 1.1032662370681763, 1.0277274811426798, 0.9417592786471048, 0.8835768776893616, 0.8199153347969055, 0.7389909559567769, 0.6506730312029521, 0.6172625790278117, 0.5497963446458181, 0.4896028762976328, 0.44157916858990987, 0.35436691506703694, 0.3183012537638346, 0.2650477343400319, 0.20789132913748423, 0.1588365970849991, 0.13620774028301239, 0.1060966149965922, 0.08704390456676483, 0.06249612308343252, 0.05421216632127762, 0.05546835423707962, 0.04258589466810227, 0.028359482816855113, 0.02540707011570533, 0.019701359888166188, 0.01902269349247217, 0.014140415861581762, 0.01089472517364969, 0.010010963798190156, 0.011445274929453929, 0.007484005859618385]
FedTestE1B64 = [1.955414814376831, 1.5296016119003295, 1.3785460664749145, 1.2994595100402833, 1.2108293424606322, 1.1688935831069946, 1.1281919912338256, 1.0958746099472045, 1.0859116998672484, 1.0505816764831544, 1.031676459312439, 1.0451035407066345, 1.0322404579162598, 1.0774299417495727, 1.0854945693016052, 1.0723204259872436, 1.1179626000404357, 1.1365919680595398, 1.2024104303359986, 1.2420549180984497, 1.3033364644050598, 1.3655395665168761, 1.3881642390251159, 1.4906746997833251, 1.560192495727539, 1.6452531266212462, 1.7189314069747925, 1.7171449773788452, 1.810110788345337, 1.8407028955459594, 1.915370641708374, 2.0544872666835783, 2.106391272354126, 1.9822244716644286, 2.1316884025573732, 2.1172396383285523]
FedTestE3B64 = [1.9148120754241944, 1.1566709337234498, 1.1122137831687928, 1.2591619545936585, 1.427089705657959, 1.5427867588996886, 1.7621527479171752, 1.7659530141830444, 1.9131418162345886, 2.0347157098770143, 2.091528136253357, 2.329034348487854]
FedAccuracyE3B64 = [0.3964, 0.593, 0.6284, 0.6332, 0.6485, 0.646, 0.6403, 0.6301, 0.6391, 0.6204, 0.6335, 0.6296]

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,3,1)

plt.hlines(NFTrainMin, 0, 36, color='grey', linestyles='--', label='Non-federated baseline')

plt.plot(FedTrainE3B64, marker='o', markersize=2, label='E3 B32')
plt.plot(FedTrainE2B32, marker='o', markersize=4, label='E2 B32')
plt.plot(FedTrainE2B64, marker='o', markersize=2, label='E2 B64')
plt.plot(FedTrainE1B32, marker='o', markersize=4, label='E1 B32')
plt.plot(FedTrainE1B64, marker='o', markersize=2, label='E1 B64')
plt.legend(ncol=2)
plt.ylabel('Train Loss')
plt.xlabel('Epochs')
plt.title("Train Loss (IID)")


plt.subplot(1,3,2)
plt.hlines(NFTestMin, 0, 36, color='grey', linestyles='--', label="Non-federated baseline")

plt.plot(FedTestE3B64, marker='o', markersize=2, label='E3 B32')
plt.plot(FedTestE2B32, marker='o', markersize=4, label='E2 B32')
plt.plot(FedTestE2B64, marker='o', markersize=2, label='E2 B64')
plt.plot(FedTestE1B32, marker='o', markersize=4, label='E1 B32')
plt.plot(FedTestE1B64, marker='o', markersize=2, label='E1 B64')
plt.ylabel('Validation Loss')
plt.xlabel('Epochs')
plt.title("Validation Loss (IID)")
plt.legend(ncol=2)

plt.subplot(1,3,3)
plt.hlines(NFAccuracyMax, 0, 36, color='grey', linestyles='--', label='Non-federated baseline')

plt.plot(FedAccuracyE3B64, marker='o', markersize=2, label='E3 B32')
plt.plot(FedAccuracyE2B32, marker='o', markersize=4, label='E2 B32')
plt.plot(FedAccuracyE2B64, marker='o', markersize=2, label='E2 B64')
plt.plot(FedAccuracyE1B32, marker='o', markersize=4, label='E1 B32')
plt.plot(FedAccuracyE1B64, marker='o', markersize=2, label='E1 B64')
plt.ylabel('Validation Accuracy')
plt.xlabel('Epochs')
plt.title("Validation Accuracy (IID)")
plt.legend(ncol=2)

plt.show()

# %%
# MIA EXPERIMENT
# Attack on non-federated model


cent = [0.6136783733826248, 0.5633720930232559, 0.7291044776119403, 0.7416728349370837, 0.6875434933890049, 0.6898638426626323, 0.6202219482120839, 0.6094710947109471, 0.6156289707750953, 0.6086142322097379]
cent_average = 0.71765

cent_reg = [0.6296060991105463, 0.5960712093308779, 0.7195729537366548, 0.7866141732283465, 0.721656976744186, 0.7074102368220015, 0.6246928746928747, 0.6299810246679317, 0.6059850374064838, 0.6448160535117057]
cent_reg_average = 0.74045

ensemble = [0.5544910179640719, 0.5648351648351648, 0.5963149078726968, 0.6968911917098446, 0.6525612472160356, 0.5537190082644629, 0.5367561260210035, 0.571072319201995, 0.5361390667886551, 0.5983739837398374]
ensemble_average = 0.55145

cyc = [0.6081694402420574, 0.5738636363636364, 0.6914468425259792, 0.72544080604534, 0.7017167381974249, 0.6830154405086285, 0.6169741697416974, 0.5873213175885643, 0.5795454545454546, 0.6248062015503876]
cyc_average = 0.67435

fedE1B64 = [0.6106060606060606, 0.5665961945031712, 0.6498493975903614, 0.7562425683709869, 0.7, 0.6425419240953222, 0.5922974767596282, 0.595945945945946, 0.5775922059846903, 0.5941734417344173]
fedE1B64_average = 0.6552

fedE3B32 = [0.6344569288389513, 0.5847728726807422, 0.69108049311095, 0.7172413793103448, 0.7022603273577552, 0.6848184818481848, 0.637090909090909, 0.594859241126071, 0.5963488843813387, 0.6039867109634551]

# %%
fig, ax = plt.subplots(figsize=(16,6))


methods = [cent_reg, ensemble, cyc, fedE1B64, fedE3B32]
b = ax.boxplot(methods, widths=0.4, patch_artist=True)
#ax.scatter(x=[1, 2, 3, 4, 5, 6,7], y=[nf_acc,ens_acc, ens_acc, cyc_acc, cyc_acc, fed_acc, fed_acc], marker='*', s=200)
ax.set_xticklabels(['Centrlized Model', 'Model Averaging', 'Weight Transfer', 'Federated E1', 'Federated E3'])
ax.set_ylabel('Attack Presicion')

colors = ['#eecf9e', '#b2d8b2']

# for i, box in enumerate(b['boxes']):
#     box.set(facecolor=colors[i%2])
    
b['boxes'][0].set(hatch='/')
b['boxes'][0].set(facecolor='w')
# Out:
# [None]

# %%
non_fed_outsider = [0.6855, 0.6823333333333333, 0.6536666666666666, 0.6635, 0.6685, 0.6783333333333333, 0.6391666666666667, 0.6793333333333333, 0.6541666666666667, 0.6768333333333333]

ensemble_outsider = [0.5633333333333334, 0.5466666666666666, 0.5523333333333333, 0.5661666666666667, 0.5516666666666666, 0.568, 0.5616666666666666, 0.567, 0.5656666666666667, 0.5656666666666667]
ensemble_insider = [0.5515, 0.5563333333333333, 0.555, 0.566, 0.5643333333333334, 0.5676666666666667, 0.5646666666666667, 0.5876666666666667, 0.575, 0.5678333333333333]

transfer_outsider = [0.5295, 0.5386666666666666, 0.5455, 0.547, 0.5548333333333333, 0.5583333333333333, 0.5405, 0.5416666666666666, 0.5398333333333334, 0.5408333333333334]
transfer_insider = [0.5035, 0.5153333333333333, 0.5176666666666667, 0.5178333333333334, 0.5095, 0.5188333333333334, 0.5086666666666667, 0.5181666666666667, 0.5215, 0.5068333333333334]

# %%
plt.figure(figsize=(18,8))

plt.subplot(1,2,2)
#plt.plot(cent, color="grey",  marker='*', markersize = 6, label="Centralized Model")
plt.plot(cent_reg, marker='+', label='Centralized model', markersize = 6)
plt.plot(ensemble, marker='o', label='Model Averaging', markersize = 6)
plt.plot(cyc, marker='.', label='Weight transfer', markersize = 6)
plt.plot(fedE1B64, marker='x', label='Federated E1B64', markersize = 6)
plt.plot(fedE3B32, marker='x', label='Federated E1B32', markersize = 6)

plt.xticks(np.arange(1, 11, step=1))
plt.ylabel('Attack Precision')
plt.xlabel('Classification Labels')
plt.title("CIFAR10-MIA")
plt.legend(ncol=2)
plt.show()
